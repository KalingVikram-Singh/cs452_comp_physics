# %%
from Library_git import*
from inputfiles import*

# %%
#Sol 1
sol,number = fixedpoint_method(guess)
print("The solution is: %.4f" % sol) 

print("No of iterations:", number)
# Out:
# The solution is: 0.5671
# No of iterations: 23

# %%
# Sol 2
gaussian_quadrature(a,b,x_gauss,w_gauss)
val = simpson(b,a,n_s)
print("The integral through simpsons is: %.6f" % val)
# Out:
# The integral through gaussian quadrature is: 1.089424
# The integral through simpsons is: 1.089429

# %%
#Sol 3
for i in range(len(h)):
    X,Y = RK4_uncoupled(0,1,h[i],x_)
    printfunction(X,Y)
    # print(X,Y)
        # Display results
    print(f"\nResults for h = .1:")
    print("|   x   |   y   |")
    print("|-------|-------|")
    for x, y in zip(X, Y):
        print(f"| {x:.2f}  | {y:.5f} |")
# Out:
# Results for h = .1:
# |   x   |   y   |
# |-------|-------|
# | 0.00  | 1.00000 |
# | 0.50  | 0.91319 |
# | 1.00  | 1.07193 |
# | 1.50  | 1.34978 |
# | 2.00  | 1.61913 |
# | 2.50  | 1.83825 |
# | 3.00  | 2.00550 |
# | 3.50  | 2.12975 |
# | 4.00  | 2.22076 |
# | 4.50  | 2.28680 |
# | 5.00  | 2.33433 |
# | 5.50  | 2.36829 |
# | 6.00  | 2.39236 |
# | 6.50  | 2.40931 |
# | 7.00  | 2.42116 |
# | 7.50  | 2.42938 |
# | 8.00  | 2.43504 |
# | 8.50  | 2.43892 |
# | 9.00  | 2.44156 |
# | 9.50  | 2.44335 |
# | 10.00  | 2.44456 |
# Results for h = .1:
# |   x   |   y   |
# |-------|-------|
# | 0.00  | 1.00000 |
# | 0.20  | 0.93780 |
# | 0.40  | 0.91044 |
# | 0.60  | 0.92671 |
# | 0.80  | 0.98381 |
# | 1.00  | 1.07159 |
# | 1.20  | 1.17783 |
# | 1.40  | 1.29196 |
# | 1.60  | 1.40636 |
# | 1.80  | 1.51623 |
# | 2.00  | 1.61890 |
# | 2.20  | 1.71313 |
# | 2.40  | 1.79858 |
# | 2.60  | 1.87544 |
# | 2.80  | 1.94416 |
# | 3.00  | 2.00534 |
# | 3.20  | 2.05964 |
# | 3.40  | 2.10771 |
# ...

# %%
# Sol 4
crank_nicolson(Nx,Nt,Lx,Tx,alpha)

# alpha = 0.03125, LU decomposition is used to solve the equation Au(j+1) = Bu(j).
# Out:
# Solution in a Table:
# ...

# %%
#SOl 5
x,y,u = poisson(lx,ly,nx,ny,lx0,ly0,iterations)
# Out:
# Solution in a Table:
# 0.0000	0.0000	0.0000	0.0000	0.0000	0.0000
# 0.4000	0.4887	0.5970	0.7291	0.8904	1.0873
# 0.8000	0.9774	1.1939	1.4582	1.7808	2.1746
# 1.2000	1.4661	1.7908	2.1872	2.6712	3.2619
# 1.6000	1.9546	2.3875	2.9161	3.5614	4.3493
# 2.0000	2.4428	2.9836	3.6442	4.4511	5.4366
